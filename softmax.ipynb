# %%
import tensorflow as tf
import numpy as np
from scipy.misc import imread, imresize, imsave
import scipy.io
from scipy.io import savemat, loadmat
from os import listdir, walk
from os.path import isfile, join
#import PIL
import matplotlib.pyplot as plt
import time

start_time = time.time()

trainPath = 'data/train/'
avgImgHeight = int(360/4)       # Actual average height is 360. I am doing more downsampling
avgImgWidth = int(400/4)        # Actual average width is 400. I am doing more downsampling
imgClasses = ['dog', 'cat']
numClasses = len(imgClasses)

fileNames = next(walk(trainPath))[2]
numTrain = len(fileNames)
trainDataX = np.zeros((numTrain, avgImgHeight, avgImgWidth, 3), dtype=np.uint8)
trainDataY = np.zeros((numTrain, numClasses), dtype=np.uint8)
for i, fileName in enumerate(fileNames):
    img = imread(join(trainPath, fileName))
    img = imresize(img, (avgImgHeight, avgImgWidth))
    trainDataX[i, :, :, :] = img

    for j, imgClass in enumerate(imgClasses):
        trainDataY[i, j] = (fileName[0:3] == imgClass)

print('Time taken to load data = ', time.time()-start_time)

# %%
trainDataX = np.reshape(trainDataX, (trainDataX.shape[0], -1))

flatImgDim = trainDataX.shape[1]

learningRate = 0.00000001
numIter = 10000
batchSize = 100
X = tf.placeholder(tf.float32, [None, flatImgDim])
y = tf.placeholder(tf.float32, [None, numClasses])

W = tf.Variable(np.float32(np.random.randn(flatImgDim, numClasses)*0.001))
b = tf.Variable(tf.zeros(numClasses))

y_pred = tf.nn.softmax(tf.matmul(X,W) + b)

cross_entropy = tf.reduce_mean(-tf.reduce_sum(y * tf.log(y_pred), reduction_indices=[1]))
trainStep = tf.train.GradientDescentOptimizer(learningRate).minimize(cross_entropy)
correctPrediction = tf.equal(tf.argmax(y_pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correctPrediction, tf.float32))

init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

for i in range(numIter):
    sampleIndices = np.random.choice(np.arange(numTrain), batchSize)
    batch_xs = trainDataX[sampleIndices]
    batch_ys = trainDataY[sampleIndices]
    sess.run(trainStep, feed_dict={X: batch_xs, y: batch_ys})
    if i%100 == 0:
        print("Iteration = ", i, "Cross Entropy = ", sess.run(cross_entropy, feed_dict={X:batch_xs, y: batch_ys}),
              "Train Accuracy = ", sess.run(accuracy, feed_dict={X:batch_xs, y: batch_ys}))



print('Training accuracy with Softmax regression = ', sess.run(accuracy, feed_dict={X: trainDataX, y: trainDataY}))
# Out:
# Iteration =  0 Cross Entropy =  4.76406 Train Accuracy =  0.51
# Iteration =  100 Cross Entropy =  3.94905 Train Accuracy =  0.52
# Iteration =  200 Cross Entropy =  3.9929 Train Accuracy =  0.48
# Iteration =  300 Cross Entropy =  3.21758 Train Accuracy =  0.5
# Iteration =  400 Cross Entropy =  2.43169 Train Accuracy =  0.56
# Iteration =  500 Cross Entropy =  2.98761 Train Accuracy =  0.52
# Iteration =  600 Cross Entropy =  3.25279 Train Accuracy =  0.55
# Iteration =  700 Cross Entropy =  2.53124 Train Accuracy =  0.57
# Iteration =  800 Cross Entropy =  2.10473 Train Accuracy =  0.64
# Iteration =  900 Cross Entropy =  3.14365 Train Accuracy =  0.52
# Iteration =  1000 Cross Entropy =  2.63763 Train Accuracy =  0.54
# Iteration =  1100 Cross Entropy =  3.1464 Train Accuracy =  0.45
# Iteration =  1200 Cross Entropy =  3.09896 Train Accuracy =  0.51
# Iteration =  1300 Cross Entropy =  2.60916 Train Accuracy =  0.54
# Iteration =  1400 Cross Entropy =  2.64653 Train Accuracy =  0.58
# Iteration =  1500 Cross Entropy =  2.43221 Train Accuracy =  0.53
# Iteration =  1600 Cross Entropy =  2.2142 Train Accuracy =  0.56
# Iteration =  1700 Cross Entropy =  2.78546 Train Accuracy =  0.48
# Iteration =  1800 Cross Entropy =  2.92171 Train Accuracy =  0.53
# Iteration =  1900 Cross Entropy =  2.1533 Train Accuracy =  0.54
# Iteration =  2000 Cross Entropy =  2.75477 Train Accuracy =  0.45
# Iteration =  2100 Cross Entropy =  2.43262 Train Accuracy =  0.43
# Iteration =  2200 Cross Entropy =  2.27403 Train Accuracy =  0.59
# Iteration =  2300 Cross Entropy =  2.17698 Train Accuracy =  0.55
# Iteration =  2400 Cross Entropy =  3.15271 Train Accuracy =  0.53
# Iteration =  2500 Cross Entropy =  2.71258 Train Accuracy =  0.45
# Iteration =  2600 Cross Entropy =  2.30276 Train Accuracy =  0.59
# Iteration =  2700 Cross Entropy =  2.41712 Train Accuracy =  0.57
# Iteration =  2800 Cross Entropy =  2.6092 Train Accuracy =  0.54
# Iteration =  2900 Cross Entropy =  2.40052 Train Accuracy =  0.52
# Iteration =  3000 Cross Entropy =  2.11025 Train Accuracy =  0.5
# Iteration =  3100 Cross Entropy =  1.6675 Train Accuracy =  0.62
# Iteration =  3200 Cross Entropy =  2.48712 Train Accuracy =  0.55
# Iteration =  3300 Cross Entropy =  2.15695 Train Accuracy =  0.61
# Iteration =  3400 Cross Entropy =  2.35532 Train Accuracy =  0.56
# Iteration =  3500 Cross Entropy =  2.33847 Train Accuracy =  0.52
# Iteration =  3600 Cross Entropy =  2.15887 Train Accuracy =  0.54
# Iteration =  3700 Cross Entropy =  2.68053 Train Accuracy =  0.55
# Iteration =  3800 Cross Entropy =  1.80113 Train Accuracy =  0.51
# Iteration =  3900 Cross Entropy =  2.13232 Train Accuracy =  0.48
# Iteration =  4000 Cross Entropy =  2.37898 Train Accuracy =  0.51
# Iteration =  4100 Cross Entropy =  1.98806 Train Accuracy =  0.58
# Iteration =  4200 Cross Entropy =  2.61402 Train Accuracy =  0.53
# Iteration =  4300 Cross Entropy =  2.26393 Train Accuracy =  0.53
# Iteration =  4400 Cross Entropy =  1.6911 Train Accuracy =  0.63
# Iteration =  4500 Cross Entropy =  2.06279 Train Accuracy =  0.54
# Iteration =  4600 Cross Entropy =  2.32047 Train Accuracy =  0.52
# Iteration =  4700 Cross Entropy =  1.96455 Train Accuracy =  0.54
# Iteration =  4800 Cross Entropy =  1.86881 Train Accuracy =  0.56
# Iteration =  4900 Cross Entropy =  2.06277 Train Accuracy =  0.51
# Iteration =  5000 Cross Entropy =  2.05508 Train Accuracy =  0.54
# Iteration =  5100 Cross Entropy =  2.06505 Train Accuracy =  0.51
# Iteration =  5200 Cross Entropy =  2.45167 Train Accuracy =  0.49
# Iteration =  5300 Cross Entropy =  1.91534 Train Accuracy =  0.6
# Iteration =  5400 Cross Entropy =  2.06518 Train Accuracy =  0.6
# Iteration =  5500 Cross Entropy =  1.88804 Train Accuracy =  0.57
# Iteration =  5600 Cross Entropy =  2.45566 Train Accuracy =  0.45
# Iteration =  5700 Cross Entropy =  1.99666 Train Accuracy =  0.61
# Iteration =  5800 Cross Entropy =  2.25661 Train Accuracy =  0.53
# Iteration =  5900 Cross Entropy =  2.17834 Train Accuracy =  0.46
# Iteration =  6000 Cross Entropy =  2.03177 Train Accuracy =  0.56
# Iteration =  6100 Cross Entropy =  2.02774 Train Accuracy =  0.48
# Iteration =  6200 Cross Entropy =  1.88084 Train Accuracy =  0.53
# Iteration =  6300 Cross Entropy =  2.10223 Train Accuracy =  0.46
# Iteration =  6400 Cross Entropy =  2.49397 Train Accuracy =  0.46
# Iteration =  6500 Cross Entropy =  1.95654 Train Accuracy =  0.5
# Iteration =  6600 Cross Entropy =  1.71383 Train Accuracy =  0.56
# Iteration =  6700 Cross Entropy =  2.04803 Train Accuracy =  0.53
# Iteration =  6800 Cross Entropy =  1.50195 Train Accuracy =  0.64
# Iteration =  6900 Cross Entropy =  2.42051 Train Accuracy =  0.44
# Iteration =  7000 Cross Entropy =  1.55595 Train Accuracy =  0.56
# Iteration =  7100 Cross Entropy =  1.94923 Train Accuracy =  0.56
# Iteration =  7200 Cross Entropy =  2.20285 Train Accuracy =  0.51
# Iteration =  7300 Cross Entropy =  1.5224 Train Accuracy =  0.59
# Iteration =  7400 Cross Entropy =  1.89281 Train Accuracy =  0.58
# Iteration =  7500 Cross Entropy =  1.893 Train Accuracy =  0.55
# Iteration =  7600 Cross Entropy =  1.92951 Train Accuracy =  0.56
# Iteration =  7700 Cross Entropy =  1.60158 Train Accuracy =  0.57
# Iteration =  7800 Cross Entropy =  2.21953 Train Accuracy =  0.47
# Iteration =  7900 Cross Entropy =  1.91385 Train Accuracy =  0.56
# Iteration =  8000 Cross Entropy =  1.75028 Train Accuracy =  0.55
# Iteration =  8100 Cross Entropy =  1.75745 Train Accuracy =  0.52
# Iteration =  8200 Cross Entropy =  2.16283 Train Accuracy =  0.45
# Iteration =  8300 Cross Entropy =  2.14749 Train Accuracy =  0.53
# Iteration =  8400 Cross Entropy =  1.67123 Train Accuracy =  0.59
# Iteration =  8500 Cross Entropy =  1.50106 Train Accuracy =  0.53
# Iteration =  8600 Cross Entropy =  1.78257 Train Accuracy =  0.49
# Iteration =  8700 Cross Entropy =  1.92296 Train Accuracy =  0.54
# Iteration =  8800 Cross Entropy =  1.58485 Train Accuracy =  0.61
# Iteration =  8900 Cross Entropy =  2.23595 Train Accuracy =  0.46
# Iteration =  9000 Cross Entropy =  1.53404 Train Accuracy =  0.57
# Iteration =  9100 Cross Entropy =  1.7735 Train Accuracy =  0.56
# Iteration =  9200 Cross Entropy =  1.90528 Train Accuracy =  0.63
# Iteration =  9300 Cross Entropy =  1.8457 Train Accuracy =  0.58
# Iteration =  9400 Cross Entropy =  1.79977 Train Accuracy =  0.51
# Iteration =  9500 Cross Entropy =  1.60975 Train Accuracy =  0.55
# Iteration =  9600 Cross Entropy =  1.64955 Train Accuracy =  0.55
# Iteration =  9700 Cross Entropy =  1.65472 Train Accuracy =  0.54
# Iteration =  9800 Cross Entropy =  2.11613 Train Accuracy =  0.46
# Iteration =  9900 Cross Entropy =  1.43172 Train Accuracy =  0.64
# Training accuracy with Softmax regression =  0.5424
